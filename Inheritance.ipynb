# %%
class Student:
    def __init__(self,student_name,roll_no):
        self.student_name = student_name
        self.roll_no = roll_no
    def display_student(self):
        print("Student_Name:",self.student_name)
        print("Roll_No:",self.roll_no)
class CollegeStudent(Student):
    def __init__(self,student_name,roll_no,course_name):
        super().__init__(student_name,roll_no)
        self.course_name = course_name
    def display_course(self):
        print("Course_Name:",self.course_name)
std1 = CollegeStudent("Harshitha",101,"Computer Science Engineering")
print(std1.display_student())
print(std1.display_course())
# Out:
# Student_Name: Harshitha
# Roll_No: 101
# None
# Course_Name: Computer Science Engineering
# None

# %%
class Vehicle:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model
    def show_vehicle(self):
        print("Brand:",self.brand)
        print("Model:",self.model)
class Bike(Vehicle):
    def __init__(self,brand,model,mileage):
        Vehicle.__init__(self,brand,model)
        self.mileage = mileage
    def show_bike(self):
        self.show_vehicle()
        print("Mileage:",self.mileage)
b1 = Bike("Honda","Shine",55)
b1.show_bike()
# Out:
# Brand: Honda
# Model: Shine
# Mileage: 55

# %%
class Employee:
    def __init__(self,employee_name,salary):
        self.employee_name = employee_name
        self.salary = salary
    def display_employee(self):
        print("Employee_name:",self.employee_name)
        print("Salary:",self.salary)
class Developer(Employee):
    def __init__(self,employee_name,salary,programming_language):
        super().__init__(employee_name,salary)
        self.programming_language = programming_language
    def display_developer(self):
        self.display_employee()
        print("Programming_language:",self.programming_language)
d1 = Developer("Harshitha",50000,"Python")
d1.display_developer()
# Out:
# Employee_name: Harshitha
# Salary: 50000
# Programming_language: Python

# %%
class Bank:
    def __init__(self,account_holder,account_number):
        self.account_holder = account_holder
        self.account_number = account_number
    def intrest_rate(self):
        pass
class SBI(Bank):
    def __init__(self,account_holder,account_number):
        super().__init__(account_holder,account_number)
    def intrest_rate(self):
        print("Intrest Rate:6.5%")
sbi = SBI("Harshitha",123456789)
print(sbi.account_holder)
print(sbi.account_number)
# Out:
# Harshitha
# 123456789

# %%
class Animal:
    def __init__(self, animal_name):
        self.animal_name = animal_name

    def eat(self):
        print(self.animal_name, "is eating")


class Dog(Animal):
    def __init__(self, animal_name):
        self.animal_name = animal_name

    def bark(self):
        print(self.animal_name, "is barking")


dog = Dog("Puppy")
dog.eat()
dog.bark()
# Out:
# Puppy is eating
# Puppy is barking

# %%
class Person:
    def __init__(self,name):
        self.name = name
class Student(Person):
    def __init__(self,roll_no,name):
        super().__init__(name)
        self.roll_no = roll_no
class CollegeStudent(Student):
    def __init__(self,course_name,roll_no,name):
        super().__init__(name,roll_no)
        self.course_name = course_name
    def display_details(self):
        print(self.name)
        print(self.roll_no)
        print(self.course_name)
student = CollegeStudent("Salesforce",123,"Harshitha")
student.display_details()
# Out:
# 123
# Harshitha
# Salesforce

# %%
class Company:
    def __init__(self,company_name):
        self.company_name = company_name
class Department(Company):
    def __init__(self,company_name,department_name):
        super().__init__(company_name)
        self.department_name = department_name
class Employee(Department):
    def __init__(self,company_name,department_name,employee_name):
        super().__init__(company_name,department_name)
        self.employee_name = employee_name
    def dispaly_details(self):
        print(self.company_name)
        print(self.department_name)
        print(self.employee_name)
employee = Employee("Accenture","Data science","Harshitha")
employee. dispaly_details()
# Out:
# Accenture
# Data science
# Harshitha

# %%
from abc import ABC,abstractmethod
class Bank(ABC):
    def __init__(self,bank_name):
        self.bank_name = bank_name
    def show_intrest(self):
        pass
class SBI(Bank):
    def __init__(self,bank_name,branch_name):
        super().__init__(bank_name)
        self.branch_name = branch_name
class Customer(SBI):
    def __init__(self,bank_name,branch_name,customer_name):
        super().__init__(bank_name,branch_name)
        self.customer_name = customer_name
    def show_intrest(self):
        print("Intrest rate :6.5%")
    def display_details(self):
        print(self.bank_name)
        print(self.branch_name)
        print(self.customer_name)
        self.show_intrest()
cs = Customer("RBI","Ameerpet","Harshitha")
cs. display_details()
# Out:
# RBI
# Ameerpet
# Harshitha
# Intrest rate :6.5%

# %%
class Product:
    def __init__(self,product_name):
        self.product_name = product_name
class Electronics(Product):
    def __init__(self,warranty,product_name):
        Product.__init__(self,product_name)
        self.warranty = warranty
class Mobile(Electronics):
    def __init__(self,price,warranty,product_name):
        Electronics.__init__(self,product_name,warranty)
        self.price = price
    def display_details(self):
        print(self.product_name)
        print(self.warranty)
        print(self.price)
mob = Mobile(20000,"3 years","Realme")
mob.display_details()
# Out:
# 3 years
# Realme
# 20000

# %%
from abc import ABC, abstractmethod

class Hospital(ABC):
    def __init__(self, hospital_name):
        self.hospital_name = hospital_name

    @abstractmethod
    def show_specialization(self):
        pass


class Doctor(Hospital):
    def __init__(self, hospital_name, doctor_name):
        super().__init__(hospital_name)
        self.doctor_name = doctor_name

    def show_specialization(self):
        print("General Doctor")


class Cardiologist(Doctor):
    def __init__(self, hospital_name, doctor_name, experience):
        super().__init__(hospital_name, doctor_name)
        self.experience = experience

    def show_specialization(self):
        print("Specialization: Cardiology")

    def show_all_details(self):
        print("Hospital Name:", self.hospital_name)
        print("Doctor Name:", self.doctor_name)
        print("Experience:", self.experience, "years")
        self.show_specialization()


c1 = Cardiologist("Gandhi Hospital", "Dr.Anupama", 12)
c1.show_all_details()
# Out:
# Hospital Name: Gandhi Hospital
# Doctor Name: Dr.Anupama
# Experience: 12 years
# Specialization: Cardiology
