# %%
class Father:
    def __init__(self,father_name,father_age):
        self.father_name = father_name
        self.father_age = father_age
class Mother:
    def __init__(self,mother_name,mother_age):
        self.mother_name = mother_name
        self.mother_age = mother_age
class Child(Father,Mother):
    def __init__(self,father_name,father_age,mother_name,mother_age,child_name):
        Father.__init__(self,father_name,father_age)
        Mother.__init__(self,mother_name,mother_age)
        self.child_name = child_name
    def display_all_details(self):
        print(self.father_name)
        print(self.father_age)
        print(self.mother_name)
        print(self.mother_age)
        print(self.child_name)
c = Child("Srinivasarao",55,"Sailaja",45,"Harshitha")
c.display_all_details()
# Out:
# Srinivasarao
# 55
# Sailaja
# 45
# Harshitha

# %%
class Teacher:
    def __init__(self,teaching_subject):
        self.teaching_subjcet = teaching_subject
class Engineer:
    def __init__(self,programming_language):
        self.programming_language = programming_language
class Student(Teacher,Engineer):
    def __init__(self,teaching_subject,programming_language,student_name):
        Teacher.__init__(self,teaching_subject)
        Engineer.__init__(self,programming_language)
        self.student_name = student_name
    def display_all_details(self):
        print(self.teaching_subjcet)
        print(self.programming_language)
        print(self.student_name)
s = Student("Data science","Python","Harshitha")
s.display_all_details()
# Out:
# Data science
# Python
# Harshitha

# %%
class Mobile:
    def __init__(self,mobile_brand):
        self.mobile_brand = mobile_brand
class Laptop:
    def __init__(self,laptop_brand):
        self.laptop_brand = laptop_brand
class Electronics(Mobile,Laptop):
    def __init__(self,mobile_brand,laptop_brand,owner_name):
        Mobile.__init__(self,mobile_brand)
        Laptop.__init__(self,laptop_brand)
        self.owner_name = owner_name
    def display_all_details(self):
        print(self.mobile_brand)
        print(self.laptop_brand )
        print(self.owner_name)
e = Electronics("Realme","Asus","Harshitha")
e.display_all_details()
# Out:
# Realme
# Asus
# Harshitha

# %%
class CricketPlayer:
    def __init__(self,cricket_team):
        self.cricket_team = cricket_team
class FootballPlayer:
    def __init__(self,football_team):
        self.football_team = football_team
class Athlete(CricketPlayer,FootballPlayer):
    def __init__(self,player_name,cricket_team,football_team):
        CricketPlayer.__init__(self,cricket_team)
        FootballPlayer.__init__(self,football_team)
        self.player_name = player_name
    def display_all_details(self):
        print(self.cricket_team)
        print(self.football_team)
        print( self.player_name)
at = Athlete("Rahul","India","Benguluru FC")
at.display_all_details()
# Out:
# India
# Benguluru FC
# Rahul

# %%
class BankAccount:
    def __init__(self,account_number):
        self.account_number = account_number
class Loan:
    def __init__(self,loan_amount):
        self.loan_amount = loan_amount
class Customer(BankAccount,Loan):
    def __init__(self,account_number,loan_amount,customer_name):
        BankAccount.__init__(self,account_number)
        Loan.__init__(self,loan_amount)
        self.customer_name = customer_name
    def display_all_details(self):
        print(self.account_number)
        print(self.loan_amount)
        print(self.customer_name)
c = Customer(1234567890,200000,"Harshitha")
c.display_all_details()
# Out:
# 1234567890
# 200000
# Harshitha

# %%
class Vehicle:
    def __init__(self,vehicle_number):
        self.vehicle_number = vehicle_number
class Insurance:
    def __init__(self,policy_number):
        self.policy_number = policy_number
class Car(Vehicle,Insurance):
    def __init__(self,owner_name,vehicle_number,policy_number):
        Vehicle.__init__(self,vehicle_number)
        Insurance.__init__(self,policy_number)
        self.owner_name = owner_name
    def display_all_details(self):
        print( self.vehicle_number)
        print( self.policy_number)
        print(self.owner_name)
c = Car("Harshitha",12345,9876543210)
c.display_all_details()
# Out:
# 12345
# 9876543210
# Harshitha

# %%
class School:
    def __init__(self,school_name):
        self.school_name = school_name
class Hostel:
    def __init__(self,room_number):
        self.room_number = room_number
class Student(School,Hostel):
    def __init__(self,student_name,school_name,room_number):
        School.__init__(self,school_name)
        Hostel.__init__(self,room_number)
        self.student_name = student_name
    def display_all_details(self):
        print( self.school_name )
        print(self.room_number)
        print(  self.student_name)
s = Student("Dr.k.k.r gowtham",101,"Harshitha")
s. display_all_details()
# Out:
# 101
# Harshitha
# Dr.k.k.r gowtham

# %%
class YouTubeCreator:
    def __init__(self,subscribers):
        self.subscribers = subscribers
class Blogger:
    def __init__(self,blog_name):
        self.blog_name = blog_name
class Influencer(YouTubeCreator,Blogger):
    def __init__(self,influencer_name,blog_name,subscribers):
        YouTubeCreator.__init__(self,subscribers)
        Blogger.__init__(self,blog_name)
        self.influencer_name = influencer_name
    def display_all_details(self):
        print(self.subscribers)
        print(self.blog_name)
        print(self.influencer_name)
i = Influencer("Harshitha","blog","sruthi")
i.display_all_details()
# Out:
# sruthi
# blog
# Harshitha

# %%
class Doctor:
    def __init__(self, specialization):
        self.specialization = specialization

class Researcher:
    def __init__(self, research_area):
        self.research_area = research_area

class Scientist(Doctor, Researcher):
    def __init__(self, scientist_name, specialization, research_area):
        Doctor.__init__(self, specialization)
        Researcher.__init__(self, research_area)
        self.scientist_name = scientist_name

    def display_all_details(self):
        print("Scientist Name:", self.scientist_name)
        print("Specialization:", self.specialization)
        print("Research Area:", self.research_area)

sc = Scientist("Harshitha", "Neurologist", "Nervous System")
sc.display_all_details()
# Out:
# Scientist Name: Harshitha
# Specialization: Neurologist
# Research Area: Nervous System

# %%
from abc import ABC, abstractmethod
class Bank(ABC):
    def __init__(self,bank_name):
        self.bank_name = bank_name
    def show_bank_details(self):
        pass
class Insurance:
    def __init__(self,policy_name):
        self.policy_name = policy_name
class Customer(Bank,Insurance):
    def __init__(self,customer_name,bank_name,policy_name):
        Bank.__init__(self,bank_name)
        Insurance.__init__(self,policy_name)
        self.customer_name = customer_name
    def show_bank_details(self):
        print(self.bank_name)
    def display_all_details(self):
        print(self.bank_name)
        print(self.policy_name)
        print(self.customer_name)
        self.show_bank_details
c1 = Customer("Harshitha","SBI","Life Insurance")
c1. display_all_details()
# Out:
# SBI
# Life Insurance
# Harshitha

# %%
class Animal:
    def __init__(self,animal_name):
        self.animal_name = animal_name
    def make_sound(self):
        pass
class Pet:
    def __init__(self,owner_name):
        self.owner_name = owner_name
class Dog(Animal,Pet):
    def __init__(self,animal_name,owner_name):
        Animal.__init__(self,animal_name)
        Pet.__init__(self,owner_name)
    def make_sound(self):
        print(self.make_sound)
    def display_all_details(self):
        print(self.animal_name)
        print(self.owner_name)
        self.make_sound
d1 = Dog("Dog","Harshitha")
d1. display_all_details()
# Out:
# Dog
# Harshitha

# %%
class Employee(ABC):
    def __init__(self,employee_name):
        self.employee_name = employee_name
    def work(self):
        pass
class Department:
    def __init__(self,department_name):
        self.department_name = department_name
class Manager(Employee,Department):
    def __init__(self,employee_name,department_name):
         Employee.__init__(self,employee_name)
         Department.__init__(self,department_name)
    def work(self):
        print(self.work)
    def display_all_details(self):
        print(self.employee_name)
        print(self.department_name)
        self.work()
m1 = Manager("Harshitha","Data science")
m1.display_all_details()
# Out:
# Harshitha
# Data science
# <bound method Manager.work of <__main__.Manager object at 0x0000019D0D8D2900>>

# %%
class Course(ABC):
    def __init__(self, course_name):
        self.course_name = course_name

    def duration(self):
        pass


class Institute:
    def __init__(self, institute_name):
        self.institute_name = institute_name


class Student(Course, Institute):
    def __init__(self, student_name, course_name, institute_name):
        Course.__init__(self, course_name)
        Institute.__init__(self, institute_name)
        self.student_name = student_name

    def duration(self):
        print("Course Duration: 6 Months")

    def display_all_details(self):
        print("Student Name:", self.student_name)
        print("Course Name:", self.course_name)
        print("Institute Name:", self.institute_name)
        self.duration()


s1 = Student("Harshitha", "Data Science", "Vignan")
s1.display_all_details()
# Out:
# Student Name: Harshitha
# Course Name: Data Science
# Institute Name: Vignan
# Course Duration: 6 Months

# %%
class Vehicle(ABC):
    def __init__(self,brand):
        self.brand = brand
    def start(self):
        pass
class FuelSystem:
    def __init__(self,fuel_type):
        self.fuel_type = fuel_type
class Car(Vehicle,FuelSystem):
    def __init__(self,model,brand,fuel_type):
        Vehicle.__init__(self,brand)
        FuelSystem.__init__(self,fuel_type)
        self.model = model
    def start(self):
        print(self.start)
    def display_all_details(self):
        print(self.brand)
        print(self.fuel_type)
        print(self.model)
        self.start()
c = Car(2026,"Swift","Diesel")
c.display_all_details()
# Out:
# Swift
# Diesel
# 2026
# <bound method Car.start of <__main__.Car object at 0x0000019D0D09B230>>
